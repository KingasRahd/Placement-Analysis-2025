# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Pnew.csv')

# %%
df.shape
# Out:
# (829, 14)

# %%
df.head()
# Out:
#               Course  Unnamed: 1       Discipline  Unnamed: 3  Unnamed: 4  \
# 0  Integrated M.Tech         NaN  Applied Geology         NaN         NaN
# 1  Integrated M.Tech         NaN  Applied Geology         NaN         NaN
# 2  Integrated M.Tech         NaN  Applied Geology         NaN         NaN
# 3  Integrated M.Tech         NaN  Applied Geology         NaN         NaN
# 4  Integrated M.Tech         NaN  Applied Geology         NaN         NaN
#
#    CGPA Company [on-campus/ off-campus/PPO]  Unnamed: 7  \
# 0  8.60                              Axtria         NaN
# 1  7.31                          Merilytics         NaN
# 2  8.53                          Merilytics         NaN
# 3  7.52                           Quantiphi         NaN
# 4  7.92                            Sprinklr         NaN
#
#                          Profile  Unnamed: 9  CTC Offered  Unnamed: 11  \
# 0                            NaN         NaN        14.75          NaN
# ...

# %%
df2=pd.read_csv('P2new.csv')

# %%
df2.shape
# Out:
# (58, 13)

# %%
df2.head()
# Out:
#    Course             Discipline  Unnamed: 2  CGPA  \
# 0  B.Tech  Petroleum Engineering         NaN  7.96
# 1  B.Tech  Petroleum Engineering         NaN  6.63
# 2  B.Tech  Petroleum Engineering         NaN  7.18
# 3  B.Tech  Petroleum Engineering         NaN  7.25
# 4  B.Tech  Petroleum Engineering         NaN  7.36
#
#   Company [on-campus/ off-campus/PPO]  Unnamed: 5  Unnamed: 6  \
# 0                              Meesho         NaN         NaN
# 1                                ONGC         NaN         NaN
# 2                                ONGC         NaN         NaN
# 3                                ONGC         NaN         NaN
# 4                                ONGC         NaN         NaN
#
#             Profile  Unnamed: 8  CTC Offered  Unnamed: 10 Type of Offer  \
# 0               NaN         NaN         37.0          NaN     On-Campus
# 1  AEE (Production)         NaN         25.0          NaN     On-Campus
# ...

# %%
df.drop(columns=df.columns[[1,3,4,7,9,11,13]],inplace=True)

# %%
df
# Out:
#                 Course       Discipline  CGPA  \
# 0    Integrated M.Tech  Applied Geology  8.60
# 1    Integrated M.Tech  Applied Geology  7.31
# 2    Integrated M.Tech  Applied Geology  8.53
# 3    Integrated M.Tech  Applied Geology  7.52
# 4    Integrated M.Tech  Applied Geology  7.92
# ..                 ...              ...   ...
# 824                NaN              NaN   NaN
# 825                NaN              NaN   NaN
# 826                NaN              NaN   NaN
# 827                NaN              NaN   NaN
# 828                NaN              NaN   NaN
#
#     Company [on-campus/ off-campus/PPO]                        Profile  \
# 0                                Axtria                            NaN
# 1                            Merilytics        Senior Business Analyst
# 2                            Merilytics  Senior Analyst - Data Science
# 3                             Quantiphi               Business Analyst
# ...

# %%
df2.drop(columns=df2.columns[[2,5,6,8,10,12]],axis=1,inplace=True)

# %%
df2
# Out:
#     Course             Discipline  CGPA Company [on-campus/ off-campus/PPO]  \
# 0   B.Tech  Petroleum Engineering  7.96                              Meesho
# 1   B.Tech  Petroleum Engineering  6.63                                ONGC
# 2   B.Tech  Petroleum Engineering  7.18                                ONGC
# 3   B.Tech  Petroleum Engineering  7.25                                ONGC
# 4   B.Tech  Petroleum Engineering  7.36                                ONGC
# 5   B.Tech  Petroleum Engineering  7.40                                ONGC
# 6   B.Tech  Petroleum Engineering  7.59                                ONGC
# 7   B.Tech  Petroleum Engineering  7.70                                ONGC
# 8   B.Tech  Petroleum Engineering  7.74                                ONGC
# 9   B.Tech  Petroleum Engineering  7.79                                ONGC
# 10  B.Tech  Petroleum Engineering  7.98                                ONGC
# ...

# %%
df.iloc[770,:]
# Out:
# Course                                 NaN
# Discipline                             NaN
# CGPA                                   NaN
# Company [on-campus/ off-campus/PPO]    NaN
# Profile                                NaN
# CTC Offered                            NaN
# Type of Offer                          NaN
# Name: 770, dtype: object

# %%
df.drop(df.index[770:],inplace=True)

# %%
df
# Out:
#                 Course             Discipline  CGPA  \
# 0    Integrated M.Tech        Applied Geology  8.60
# 1    Integrated M.Tech        Applied Geology  7.31
# 2    Integrated M.Tech        Applied Geology  8.53
# 3    Integrated M.Tech        Applied Geology  7.52
# 4    Integrated M.Tech        Applied Geology  7.92
# ..                 ...                    ...   ...
# 765             B.Tech  Petroleum Engineering  7.56
# 766             B.Tech  Petroleum Engineering  7.90
# 767             B.Tech  Petroleum Engineering  7.27
# 768             B.Tech  Petroleum Engineering  7.80
# 769             B.Tech  Petroleum Engineering  8.11
#
#     Company [on-campus/ off-campus/PPO]                        Profile  \
# 0                                Axtria                            NaN
# 1                            Merilytics        Senior Business Analyst
# 2                            Merilytics  Senior Analyst - Data Science
# ...

# %%
df=pd.concat([df,df2])

# %%
df.shape
# Out:
# (828, 7)

# %%
df.isnull().sum()
# Out:
# Course                                   4
# Discipline                               4
# CGPA                                     6
# Company [on-campus/ off-campus/PPO]      4
# Profile                                532
# CTC Offered                              7
# Type of Offer                            4
# dtype: int64

# %%
df[df['Course'].isnull()]
# Out:
#     Course Discipline  CGPA Company [on-campus/ off-campus/PPO] Profile  \
# 708    NaN        NaN   NaN                                 NaN     NaN
# 709    NaN        NaN   NaN                                 NaN     NaN
# 710    NaN        NaN   NaN                                 NaN     NaN
# 711    NaN        NaN   NaN                                 NaN     NaN
#
#      CTC Offered Type of Offer
# 708          NaN           NaN
# 709          NaN           NaN
# 710          NaN           NaN
# 711          NaN           NaN

# %%
df.drop(index=[708,709,710,711],inplace=True)

# %%
df
# Out:
#                Course             Discipline  CGPA  \
# 0   Integrated M.Tech        Applied Geology  8.60
# 1   Integrated M.Tech        Applied Geology  7.31
# 2   Integrated M.Tech        Applied Geology  8.53
# 3   Integrated M.Tech        Applied Geology  7.52
# 4   Integrated M.Tech        Applied Geology  7.92
# ..                ...                    ...   ...
# 53             B.Tech  Petroleum Engineering  7.71
# 54             B.Tech  Petroleum Engineering  7.71
# 55             B.Tech  Petroleum Engineering  6.78
# 56             B.Tech  Petroleum Engineering  6.85
# 57             B.Tech  Petroleum Engineering  7.15
#
#    Company [on-campus/ off-campus/PPO]                        Profile  \
# 0                               Axtria                            NaN
# 1                           Merilytics        Senior Business Analyst
# 2                           Merilytics  Senior Analyst - Data Science
# ...

# %%
df.isnull().sum()
# Out:
# Course                                   0
# Discipline                               0
# CGPA                                     2
# Company [on-campus/ off-campus/PPO]      0
# Profile                                528
# CTC Offered                              3
# Type of Offer                            0
# dtype: int64

# %%
df.describe()
# Out:
#              CGPA  CTC Offered
# count  822.000000   821.000000
# mean     7.762762    19.192046
# std      0.787772    11.070423
# min      5.640000     0.000000
# 25%      7.250000    10.000000
# 50%      7.790000    16.000000
# 75%      8.360000    25.000000
# max      9.650000   100.000000

# %%
df.rename(columns={'Company [on-campus/ off-campus/PPO]':'Company','CTC Offered':'CTC','Type of Offer':'Type'},inplace=True)

# %%
a=np.array([1,2,3])

# %%
np.mean(a)
# Out:
# np.float64(2.0)

# %%
df['CTC'].fillna(df['CTC'].median(),inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1616\3493002575.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CTC'].fillna(df['CTC'].median(),inplace=True)

# %%
df['CGPA'].fillna(df['CGPA'].median(),inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1616\1025939748.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CGPA'].fillna(df['CGPA'].median(),inplace=True)

# %%
df['Profile'].fillna('NA',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1616\492640228.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Profile'].fillna('NA',inplace=True)

# %%
df.isnull().sum()
# Out:
# Course        0
# Discipline    0
# CGPA          0
# Company       0
# Profile       0
# CTC           0
# Type          0
# dtype: int64

# %%
df
# Out:
#                Course             Discipline  CGPA              Company  \
# 0   Integrated M.Tech        Applied Geology  8.60               Axtria
# 1   Integrated M.Tech        Applied Geology  7.31           Merilytics
# 2   Integrated M.Tech        Applied Geology  8.53           Merilytics
# 3   Integrated M.Tech        Applied Geology  7.52            Quantiphi
# 4   Integrated M.Tech        Applied Geology  7.92             Sprinklr
# ..                ...                    ...   ...                  ...
# 53             B.Tech  Petroleum Engineering  7.71            Essar enp
# 54             B.Tech  Petroleum Engineering  7.71            Essar enp
# 55             B.Tech  Petroleum Engineering  6.78  Cubation Consulting
# 56             B.Tech  Petroleum Engineering  6.85  Cubation Consulting
# 57             B.Tech  Petroleum Engineering  7.15  Cubation Consulting
#
#                           Profile    CTC       Type
# ...

# %%
df['Profile'].replace({'0':'NA'},inplace=True)

# %%
df.fillna('NA',inplace=True)

# %%
df['Profile'] = df['Profile'].replace({
    'SDE': 'Software Engineer',
    'SDE-I': 'Software Engineer',
    'Software Developer': 'Software Engineer',
    'Software Develpoment Engineer': 'Software Engineer',
    'Software Develper': 'Software Engineer',
    'GET - SDE I – Digital Transformation': 'Software Engineer',
    'Developer- Trainee': 'Software Engineer',
    'Web Engineer': 'Software Engineer',
    'ASE': 'Software Engineer',
    'Associate Developer': 'Software Engineer',
    'ERS SEMI': 'Software Engineer',
    'SRIB': 'Software Engineer',
    'Member of Technical Staff': 'Software Engineer',
    'Softwarisation': 'Software Engineer',
    
    'Analyst L1': 'Analyst',
    'Data Analyst': 'Analyst',
    'Senior Analyst - Data Science': 'Analyst',
    'DSA': 'Analyst',
    'Trainee Analyst': 'Analyst',
    
    'Product Analyst': 'Business Analyst',
    'Business Analyst': 'Business Analyst',
    'Senior Business Analyst': 'Business Analyst',
    'Associate Consultant': 'Business Analyst',
    'Associate Business Manager': 'Business Analyst',
    'Knowledge Associate': 'Business Analyst',
    
    'Management Traniee': 'Management Trainee',
    
    'AEE (Reservoir)': 'Assistant Executive Engineer',
    'AEE (Production)': 'Assistant Executive Engineer', 
    'AEE (Drilling)': 'Assistant Executive Engineer',
    
    'GET': 'Graduate Engineer Trainee',
    'Engineer Trainee': 'Graduate Engineer Trainee',
    
    'Eletcrical & mechatronic': 'Electrical Engineer',
    'IT Engineer': 'Engineer',
    'Project Engineer': 'Engineer',
    'Mechanical Engineer': 'Engineer',
    
    'Ericssion': 'Other',
    'Base++': 'Other',
    'CDMA Hetran': 'Other',
    'Associate': 'Other',
})

# %%
df['Profile'].unique()
# Out:
# array(['NA', 'Business Analyst', 'Analyst', 'Geophysicist (Surface)',
#        'Geophysicist (Wells)', 'APM', 'Software Engineer',
#        'Senior Technical Associate', 'Graduate Engineer Trainee',
#        'Management Trainee Technical', 'Other', 'R&D Engineer',
#        'Product Engineer', 'Engineer', 'Management Trainee', 'Analytics',
#        'Electrical Engineer', 'Data Engineers', 'Risk', 'Faculty',
#        'Internal Audit', 'Business Developer',
#        'Associate Program Manager', 'Assistant Executive Engineer',
#        'AEE (Reservior)'], dtype=object)

# %%
df['CTC'].replace({0:'NA'},inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1616\1246101742.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CTC'].replace({0:'NA'},inplace=True)

# %%
df.to_csv('Placements.csv',index=False)
